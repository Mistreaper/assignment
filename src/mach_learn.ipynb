# %%
import pandas as pd
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
from sklearn.metrics import r2_score
np.random.seed = 2

df = pd.read_csv("https://www.w3schools.com/python/pandas/data.csv.txt")
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

x = np.random.normal(3, 1, 100)
y = np.random.normal(150, 40, 100) / x

train_x = x[:75]
train_y = y[:75]
test_x = x[75:]
test_y = y[75:]


mymodel = np.poly1d(np.polyfit(train_x, train_y, 3))
myline = np.linspace(0, 5, 100)

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y)
plt.plot(myline, mymodel(myline))

r2 = r2_score(train_y, mymodel(train_x))
print(r2)

r2_test = r2_score(test_y, mymodel(test_x))
print(r2_test)

plt.show()
# Out:
# 0.830540467764792
# -0.10091890380504531

# %%
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

titanic = pd.read_csv("titanic3.csv")
titanic.dropna(inplace=True, subset=['sex', 'age'])
# features: sex, age
d = {'female': 1, 'male': 0}
titanic['sex'] = titanic['sex'].map(d)

features = ['sex', 'age']
X = titanic[features]
y = titanic['survived']

dtree = DecisionTreeClassifier()
dtree.fit(X.values, y)
# Out:
# DecisionTreeClassifier()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# run spider
# !scrapy.exe runspider crawler.py -o crawler.json  

bookdf = pd.read_json('crawler.json')
bookdf.dropna(inplace=True)
bookdf['price'] = bookdf['price'].str.replace('£', '')
bookdf['price'] = bookdf['price'].astype(float)

# remove string part of availability
bookdf['availability'] = bookdf['availability'].str.replace(r'\D', '').astype('int')
# Out:
# C:\Users\realm\AppData\Local\Temp\ipykernel_16376\3254047463.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   bookdf['availability'] = bookdf['availability'].str.replace(r'\D', '').astype('int')
